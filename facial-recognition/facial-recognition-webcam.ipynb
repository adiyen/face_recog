# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# %matplotlib notebook
# Out:
# /Users/sampathweb/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/style/core.py:203: UserWarning: In /Users/sampathweb/.matplotlib/stylelib/grayscale.mplstyle: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(message)
# /Users/sampathweb/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/style/core.py:203: UserWarning: In /Users/sampathweb/.matplotlib/stylelib/ggplot.mplstyle: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(message)
# /Users/sampathweb/miniconda3/envs/py36/lib/python3.6/site-packages/matplotlib/style/core.py:203: UserWarning: In /Users/sampathweb/.matplotlib/stylelib/dark_background.mplstyle: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(message)

# %%
from face_recog_utils import load_users

# %%
users = load_users("names.txt", "dataSet")
# Out:
# 1 Krisna
# <img src="data:image/png;base64,..." width="640">

# %%
users
# Out:
# [{'encoding': array([-0.11071092,  0.0772821 ,  0.03777141, -0.00167146, -0.09088774,
#          -0.01974245,  0.00406773, -0.01156452,  0.21451145, -0.09832854,
#           0.17829993,  0.01604003, -0.19285126, -0.03213251, -0.00155046,
#           0.1450561 , -0.17780161, -0.15497264, -0.03045043, -0.03799852,
#           0.10130229,  0.04553623, -0.00373432,  0.04394102, -0.10120962,
#          -0.36153039, -0.07721913, -0.16517223,  0.03889075, -0.10081398,
#           0.02795587,  0.08496054, -0.21301642, -0.06980098, -0.00700335,
#           0.05770429,  0.03749404, -0.01516587,  0.15546456,  0.05927017,
#          -0.15519473, -0.01775377, -0.0048958 ,  0.27235025,  0.04932141,
#           0.05035919,  0.02198828, -0.08602319,  0.0358756 , -0.12021092,
#          -0.00877668,  0.11053906,  0.11694551,  0.05745683,  0.06896618,
#          -0.14948356,  0.0991023 ,  0.00717775, -0.23615155,  0.07186107,
#           0.01839573, -0.04420237,  0.02432509, -0.01836488,  0.25945893,
# ...
